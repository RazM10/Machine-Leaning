# %%
import pandas as pd
import numpy as np

df_ds_m = pd.read_csv('titanic.csv')
df_ds=df_ds_m.copy()
df_ds_n=df_ds_m.copy()
df=df_ds.copy()

#df3 = df1.copy(deep='all')

#x_s=df_ds_m.iloc[:, 5].values






df = df.drop(df.columns[[10]],axis = 1)
df = df.dropna(axis=0)

y = input("Enter the Selected Feature Name: ")
_type = input("Enter the Feature Type: ")

if _type=='Nominal':
    print('Nominal')
    df_1=df_ds
    
elif _type=='Binary':
    loc=df.columns.get_loc(y)
    
    y_3=df.iloc[:,loc].values
    X = df.iloc[:,[2,9]].values
    
    myFilter_1=y_3<=18
    myFilter_2=y_3>18
    
    y_3[myFilter_1]=0
    y_3[myFilter_2]=1
    
    from sklearn import preprocessing
    lab_enc = preprocessing.LabelEncoder()
    y_3 = lab_enc.fit_transform(y_3)
    
    from sklearn.model_selection import train_test_split  
    X_train, X_test, y_train, y_test = train_test_split(X, y_3, test_size=0.20)
    
    from sklearn.neighbors import KNeighborsClassifier
    clf = KNeighborsClassifier(3, weights='distance')
    
    trained_model = clf.fit(X_train, y_train)
    
    #impute
    df_1=df_ds_m.copy()
    
    X_1 = df_1.iloc[:,[2,9]].values
    
    y_pred = trained_model.predict(X_1)
    
    df_1['newAge'] = y_pred
    
    
    
    #output
    print('Prcessed Dataset is: ')
    

else:
    loc=df.columns.get_loc(y)
    
    y_3=df.iloc[:,loc].values
    X = df.iloc[:,[2,9]].values
    
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y_3, test_size=0.2, random_state=0)
    
    from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier

    regressor = RandomForestRegressor(n_estimators=20, random_state=0)  
    regressor.fit(X_train, y_train)  
    
    #impute
    df_1=df_ds
    
    X_1 = df_1.iloc[:,[2,9]].values
    
    y_pred = regressor.predict(X_1)
    
    df_1['newAge'] = y_pred
    
    #output
    print('Prcessed Dataset is: ')
    
#df_1.head(10)

df_n=df_ds_n.copy()
x_n=df_n.Age
myFilter_3n=x_n.isnull()
x_n.replace(np.nan,-1, inplace=True)
y_3_n=df_n.iloc[:, 5].values
myFilter_1n=y_3_n<=18
myFilter_2n=y_3_n>18
y_3_n[myFilter_1n]=0
y_3_n[myFilter_2n]=1
y_3_n[myFilter_3n]= -1
df_ds_n['RealAge'] = y_3_n
df_ds_n['NewAge'] = y_pred

df_ds_n
# Out:
# Enter the Selected Feature Name: Age
# Enter the Feature Type: Numeric
# Prcessed Dataset is:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# ...

# %%
mf=df_ds['Age'].isnull()

# %%
df_ds['Real']=df_ds['Age'].copy()

# %%
df_ds['New']=df_ds['Age'].copy()

# %%
m=df_ds['New'].copy()

# %%
m[mf]=df_ds['newAge']

# %%
df_ds['New']=m

# %%
df_ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
