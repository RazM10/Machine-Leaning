# %%
import pandas as pd
import numpy as np

df_ds = pd.read_csv('titanic.csv')
df=df_ds.copy()
df = df.drop(df.columns[[10]],axis = 1)
df = df.dropna(axis=0)

# %%
from itertools import groupby

def soundex(word):
   codes = ("bfpv","cgjkqsxz", "dt", "l", "mn", "r")
   soundDict = dict((ch, str(ix+1)) for ix,cod in enumerate(codes) for ch in cod)
   cmap2 = lambda kar: soundDict.get(kar, '9')
   sdx =  ''.join(cmap2(kar) for kar in word.lower())
   sdx2 = word[0].upper() + ''.join(k for k,g in list(groupby(sdx))[1:] if k!='9')
   sdx3 = sdx2[0:4].ljust(4,'0')
   return sdx3

#soundex("smith")#enter smith||smythe or smoething like that
# Out:
# 'S530'

# %%
df_ds['Name'] = df_ds['Name'].map(soundex).copy()

# %%
df_ds
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3  B653    male  22.0      1      0
# 1              2         1       1  C552  female  38.0      1      0
# 2              3         1       3  H255  female  26.0      0      0
# 3              4         1       1  F364  female  35.0      1      0
# 4              5         0       3  A455    male  35.0      0      0
# 5              6         0       3  M655    male   NaN      0      0
# 6              7         0       1  M263    male  54.0      0      0
# 7              8         0       3  P425    male   2.0      3      1
# 8              9         1       3  J525  female  27.0      0      2
# 9             10         1       2  N265  female  14.0      1      0
# 10            11         1       3  S532  female   4.0      1      1
# 11            12         1       1  B545  female  58.0      0      0
# 12            13         0       3  S536    male  20.0      0      0
# ...
